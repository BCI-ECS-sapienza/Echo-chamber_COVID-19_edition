# %% [markdown]
# # My Louvain Implementation

# %% [markdown]
# ### Import

# %%
import os
import pickle
import math
from tqdm import tqdm
from google.colab import drive
from collections import Counter, defaultdict

# graph files folder
drive.mount('/content/drive')
graph_files = '/content/drive/My Drive/covid_project/graph_files'
community_detection = '/content/drive/My Drive/covid_project/community_detection'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Convert dictionary file to Counter structure

# %%
with open(graph_files+"/graph.pickle", "rb") as f:
  G = pickle.load(f)

for item in G:
  for i in G[item]:
    G[item][i] = G[item][i]['weight']
  tmp = Counter(G[item])
  G[item] = tmp

with open(community_detection+"graph_counter.pickle", "wb") as f:
  pickle.dump(G, f)

# %% [markdown]
# ### My Louvain

# %%
"""### Initialization"""

# In the case of first init we have to initialize also the communities
def first_init(G):
  communities = {}
  super_nodes = defaultdict(list)

  sum_in = {}                 # sum of link weights between nodes in 𝐶
  sum_tot = Counter()         # sum of all link weights of nodes in 𝐶
  k_in = {}                   # sum of link weights between node 𝑖 and 𝐶
  k_i = {}                    # sum of all link weights (i.e., degree) of node 𝑖

  for v in G:
      communities[v] = v      # At the beginning every node is a community
      sum_in[v] = 0
      k_i[v] = 0
      k_in[v] = Counter()
      for w in G[v]:
          k_i[v] += G[v][w]
          sum_tot[v] += G[v][w]
          k_in[v][w] = G[v][w]

  return communities, super_nodes, sum_in, sum_tot, k_i, k_in

def init(G):
  sum_in = {}                 
  sum_tot = Counter()         
  k_i = {}
  k_in = {}

  for v in G:
      sum_in[v] = 0
      k_i[v] = 0
      k_in[v] = Counter()
      for w in G[v]:
          k_i[v]+= G[v][w]
          sum_tot[v]+= G[v][w]
          k_in[v][w] = G[v][w]

  return sum_in, sum_tot, k_i, k_in


"""### PHASE 1
Put each node in a graph into a distinct community (one node per community). For each node v, the algorithm performs two calculations:

- Compute the modularity delta (∆𝑄) when putting node v into the community of some neighbor w
- Move v to the community of node w that yields the largest gain in ∆𝑄
"""
def P1(G, communities, sum_in, sum_tot, k_i, k_in):

  converged = False
  ok = 0
  stop = 0

  # This m corresponds to the number of edges, we need it to calculate modularity
  m = 0
  for i in G:
      for j in G[i]:
          if i < j:
              m+=G[i][j]
  
  while not converged:
    converged = True
    ok += 1

    # Needed for the statistics
    n_nodes = len(G.keys())
    updates = 0

    for v, neighbors in tqdm(G.items()):        
      max_modularity = -1
      old_modularity = 0
      max_community = None

      for w in neighbors:
        C = communities[w]

        # Modularity moving node v into the community C of the neighbor w
        gain = (sum_in[C] + k_in[v][C])/(2*m) - pow(((sum_tot[C]+k_i[v])/(2*m)),2)
        loss = (sum_in[C])/(2*m) - pow((sum_tot[C])/(2*m),2) - pow((k_i[v])/(2*m),2)

        modularity = gain - loss

        # Update max_modularity and max_community, if moving node v into the community C of the neighbor w increase the curr modularity
        if (modularity > max_modularity):
          max_modularity = modularity
          max_community = communities[w]
      
      # Change the community of v if the max_modularity is greather than 0, then update the values
      if max_modularity > 0 and (max_community != communities[v]):
        updates += 1
        old_community = communities[v]
        communities[v] = max_community
        converged = False

        for w in neighbors:
            weight = G[v][w]

            # update sum_in
            if communities[w] == old_community:
                sum_in[old_community] -= weight
            if communities[w] == max_community:
                sum_in[max_community] += weight

            # update sum_tot
            if communities[w] != old_community and communities[w] != max_community:
                sum_tot[old_community] -= weight
                sum_tot[max_community] += weight
            elif communities[w] == old_community:
                sum_tot[old_community] += weight
                sum_tot[max_community] += weight
            elif communities[w] == max_community:
                sum_tot[old_community] -= weight
                sum_tot[max_community] -= weight

            # update k_in
            k_in[w][old_community] -= weight
            k_in[w][max_community] += weight
    
    stop += 1
    if stop >= 100: converged = True
  
    '''
    # statistics
    perc = updates/n_nodes
    print(f"Updates per iteration:    {updates}")
    print(f"% update    :    {perc*100}%")
    '''

  # If the 'for' iteration are at least 2 continue with phase2, otherwise break
  if ok > 1:
    return communities, True
  else:
    return communities, False



"""### Phase 2
The communities obtained in the first phase are contracted into super-nodes, and the network is created accordingly:

- Super-nodes are connected if there is at least one edge between the nodes of the corresponding communities
- The weight of the edge between the two super-nodes is the sum of the weights from all edges between their corresponding communities
- Phase 1 is then run on the super-node network
"""

def P2(G, communities, super_nodes):

  G_new = {}
  
  # Update communities of merged nodes
  for node in tqdm(G):
    if node != communities[node]:
      merged_nodes = super_nodes[node]

      for merged_node in merged_nodes:
        communities[merged_node] = communities[node]
      
      super_nodes[communities[node]].extend(merged_nodes)
      del super_nodes[node]

  # Set community graph nodes
  for c in set(communities.values()):
    G_new[c] = Counter()

  for v in tqdm(list(G)):
    cv = communities[v]
    for w in G[v]:
      cw = communities[w]
      
      if cv != cw:
        G_new[cv][cw] += 1
        G_new[cw][cv] += 1

    del G[v]

  return G_new, communities, super_nodes



"""### Louvain method"""

def louvain(G):

  communities, super_nodes, sum_in, sum_tot, k_i, k_in = first_init(G)
  iter = 0

  while True:
      iter += 1

      communities, ok = P1(G, communities, sum_in, sum_tot, k_i, k_in)

      if not ok:
          break

      G, communities, super_nodes = P2(G, communities, super_nodes)

      sum_in, sum_tot, k, kin = init(G)
      print(f"# Total iteration: {iter}")
  return communities


''' Print communities '''
def print_communities(communities):

  output = []
  for c in communities:
    if communities[c] not in output:
      output.append(communities[c])

  print(output)
  print(communities)

# %% [markdown]
# ### Test

# %%
"""### Test"""

G1 = {
    1: Counter({2:10, 3:10, 4:10, 5:1}),
    2: Counter({1:10, 3:10, 4:10, 6:1}),
    3: Counter({1:10, 2:10, 4:10}),
    4: Counter({1:10, 2:10, 3:10}),
    5: Counter({6:10, 7:10, 8:10, 1:1}),
    6: Counter({5:10, 7:10, 8:10, 2:1}),
    7: Counter({5:10, 6:10, 8:10}),
    8: Counter({5:10, 6:10, 7:10})
}

if __name__ == '__main__':
  print("TEST")
  communities = louvain(G1)
  print_communities(communities)
  exit()
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 18641.35it/s]
# 100%|██████████| 8/8 [00:00<00:00, 18117.94it/s]
# 100%|██████████| 8/8 [00:00<00:00, 55738.26it/s]
# 100%|██████████| 8/8 [00:00<00:00, 38701.77it/s]
# 100%|██████████| 2/2 [00:00<00:00, 3335.43it/s]
# TEST
# # Total iteration: 1
# [3, 7]
# {1: 3, 2: 3, 3: 3, 4: 3, 5: 7, 6: 7, 7: 7, 8: 7}

# %% [markdown]
# ### Main

# %%
print("MY LOUVAIN")
with open(community_detection+"/graph_counter.pickle", "rb") as f:
    G = pickle.load(f)

n_nodes = len(G.keys())
print(f"nodes: {n_nodes}")
n_edges = 0
for n, neigh in G.items():
    n_edges += len(neigh)
print(f"edges: {n_edges}")

communities2 = louvain(G)
n_communities2 = len(set(communities2.values()))

print(f"communities: {n_communities2}")

print_communities(communities2)

com = Counter(communities2.values())

print(com)
z = 0
for c in com:
  if com[c] > 50:
    z += 1
    print(c)
print(z)


#with open(data+"/communities.pickle", "wb") as f:
#    pickle.dump(communities, f)
# Out:
# MY LOUVAIN
# nodes: 17903
# edges: 41170
# 100%|██████████| 17903/17903 [00:00<00:00, 100568.97it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 172788.96it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 189208.54it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193807.76it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195421.78it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 189345.47it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 191829.31it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 194824.00it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 178900.08it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 180473.34it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 188244.23it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 162494.43it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 194231.37it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 185356.77it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193673.80it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 188260.75it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 190735.90it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 199127.08it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 182245.08it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 194448.15it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 164034.63it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 198772.34it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 198603.58it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 183083.12it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 200741.11it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193284.95it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 192734.77it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 196209.69it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 188666.12it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 189548.12it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 183731.77it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 186298.58it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 197775.54it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 189834.68it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195682.52it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 192673.45it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 179594.52it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 196347.70it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 186081.60it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193190.47it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 183361.64it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 194269.56it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195229.73it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 176222.33it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195476.72it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 187863.23it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193715.77it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 196677.35it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 172643.95it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 154826.03it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 152611.74it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 159853.33it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 162214.31it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 156625.77it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 163169.19it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 163475.04it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 183668.41it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 180086.40it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195174.92it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 179002.43it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 191788.15it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 198364.35it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 190109.10it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 187340.17it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 191722.05it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 191293.22it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 178409.14it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 159380.36it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 156258.78it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 149523.94it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 159365.48it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 156230.17it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 160163.26it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 162047.33it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 162030.89it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 167391.80it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 188704.52it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 191738.69it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 168318.21it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 199339.06it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 203100.23it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 202905.41it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 198509.60it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 185733.18it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195173.91it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195879.05it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 192978.97it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 194160.56it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 191072.24it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 184506.46it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 198105.82it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 187959.16it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195060.85it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193872.81it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193550.99it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 195085.68it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 193097.07it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 189195.19it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 192400.94it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 179012.67it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 875131.11it/s]
# 100%|██████████| 17903/17903 [00:00<00:00, 503686.73it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 120277.18it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 130504.05it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 142247.84it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 185911.66it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 204400.37it/s]
#   0%|          | 0/4890 [00:00<?, ?it/s]
# # Total iteration: 1
# 100%|██████████| 4890/4890 [00:00<00:00, 206258.58it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 188225.19it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 200594.12it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 227700.77it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 194074.17it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 211307.57it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 237545.42it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 992842.80it/s]
# 100%|██████████| 4890/4890 [00:00<00:00, 737509.76it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 1318217.55it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 892806.13it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 819281.34it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 777153.62it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 735692.02it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 1103954.75it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 916435.70it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 815981.87it/s]
# 100%|██████████| 4879/4879 [00:00<00:00, 595195.43it/s]
# # Total iteration: 2
# # Total iteration: 3
# # Total iteration: 4
# 100%|██████████| 4879/4879 [00:00<00:00, 984461.89it/s]
# communities: 4879
# ['Deep-Sea Civility Predator', 'Marcia Lusk', 'Preserve Our Brooklyn Neighborhoods', 'Francesco M.', 'Eric Haywood', 'Martyn McLaughlin', 'Rep. Jared Huffman', 'W. Tai', 'software_autist 🇳🇱🇺🇸', 'Ted Lieu', 'Stephanie Ruhle', 'GW School of Nursing', 'Geoffrey Miller', 'ian haydon', 'Brad Little', 'Gottfried Gillich', 'Ami👩🏿\u200d\U0001f9b2🍑💙', 'katie "downballot races" orenstein', 'Negro Kekashi 🍃', 'Iran Front Page', 'LBC News', 'Revolution Now', 'Wars on the Brink', 'Hananya Naftali', 'Philippa Gray', 'Navid Akhtar 🇵🇰', 'interRel Consulting', 'ANCX', 'Reuters', 'Danni_D', 'Heshmat Alavi', 'Scott Stedman', 'Sam Hockley-Smith', 'Lauren', 'Foxy Brown', 'Galavant', 'David Sinclair, PhD', 'Eric Roman', 'Terrence Daniels (Captain 🍀 Planet)', 'Coronavirus Updates - Alexander Higgins', 'anne anderson🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f🇺🇸', 'Giuseppe Onufrio', 'Skyleigh #BlackLivesMatter Day 128@🏠', 'พริสม์', 'भारतीय', 'Eunice Yoon', 'Yves Clément', 'muhammad faiz', 'Candace Owens', 'Flutura Kusari', 'The Fauxy', '🌼 Baby K 🌼', 'Ashish Kumar Jha #Stay_Home_and_Save_Lives', 'LinkedIn', 'BBC Reality Check', 'GOV.UK', 'Valladolid_Exterior', 'Manchester United', 'Megaphone 📣', 'James Melville', 'Eric Topol', 'WolvieHD', 'Emily Best', 'Kim Partridge', 'MKeri', 'Venture Capital', 'Dr. Dena Grayson', 'Rea Prouska', 'Duaine Carma Roberts', 'Al Arabiya English', 'China Daily', 'King Harvest Ⓥ', 'kiuku', 'Sondy Waterl', 'taran adarsh', 'Back 2 Life ✌🏼', 'Holger Hank', 'Association for Molecular Pathology', 'Donald J. Trump', 'sfhippie', 'Flagrare 🔥', 'David Johnston', 'Kasie Hunt', 'Doug Watts', 'Ellen McGirt', 'House of Beautiful Business', 'The New Indian Express', 'Daniel Rosario', 'ℳ𝓊𝓇𝓀𝓎 ℳ𝑒𝑔 ©', 'Edmonton Journal', 'James Woods', '❣️Noodle🇺🇸🇺🇸🇵🇱\U0001f90d', 'Sarah Abdallah', 'Peter Horner', 'Reed Bonee', 'The Midnight-Blue Don', 'Gabe Wachob', 'Eric Feigl-Ding', 'V7S', 'PRO Defence Tezpur (Assam/Arunachal Pradesh)', 'Sian-Elin Flint-Freel', 'Willow Curry', 'Rob Morris', 'Carolyn R Hastie', 'P R O F', 'busstrodamus w/gloves on', 'The Bureau', 'Franklin County PH', '⚛️ 𝕍𝕠𝕠𝕓𝕚𝕖 ⚛️', 'UNDP Eswatini', 'Doug Ford', 'molly payne', 'Donna Young', 'Savitri S', 'Shannon Darst', 'Priyanka Hemanti Bhatt', 'Resiliency LLC', 'Kingshills Estate Agents', 'Colin Hung', 'Senator John Cornyn', 'Kurt Sonnenburg', 'Ben Hunte', 'Molly Jong-Fast🏡', 'The Connect 🔌.', 'Rep Andy Biggs', 'Kashif N Chaudhry', 'Melissa M. Sutherland', 'Ghulam, hussain', 'Scott Shafer', 'UN Development', 'Kristina Polley', 'Sabine Slaughter', 'SeleneStone ⚔️', 'tari xoxo', 'TheChosenJuan', 'Rick Meisinger⭐⭐⭐', 'Last Surviving Braincell', 'Debora', 'Sputnik Mundo', 'AS-Source News', 'HispanoPost', 'Wongthanong', 'เอ๋งนิมของน้องเจ ▽・x・▽', 'World Health Organization (WHO)', 'Scott Hanselman', 'BBC Wildlife', 'دانیالِ رِضائی(ابو رُقَیه)', 'Bloomberg', 'Zarrar Khuhro', 'Neeld', 'IG : @frdusmn', 'Peter McSweeney', 'Forbes', 'Rheumatoid Patient', 'Don Bolduc', '關醫師 Dr.KWAN Ka Lun', 'seli', 'Matt Driscoll', 'Phillip Andrew Davis', 'Boris Johnson #StayAlert', 'Antonio Ugarte', 'Bloomberg QuickTake', 'Dr. Luc Colemont', 'Boston Herald', 'luna\U0001f992', 'Khaled Beydoun', 'arthur boyle', '2CisMe', '🇺🇸Terry McMurray🇺🇸 🏝️', 'BJP4China', 'Jewellery Compare', 'Stella Garber', 'CitiNewsroom', 'Bagwon Pro American', 'T.PRAVEEN', 'Kanchan Gupta', 'Nick Trend', 'Muin J. Khoury', 'Anthony Albanese', 'HT Entertainment', 'David Simon', 'Jameson Lopp', 'Sandip Randhawa', 'เอ็ด', 'just sagittarius things', 'Juanita Broaddrick', 'NavyLookout', 'Andy Biotech', 'Rob Cheney', 'The Brown Institute', 'Shannon Maher Bañaga', '𝓫𝓲𝓵𝓫𝓸𝓯𝓪𝓰𝓰𝓲𝓷𝓼//ACAB', 'Mo’®️', 'NCPA', 'knayha mongha', 'National Education Finance Academy', 'RCN London', 'Timothy Caulfield', 'SkyNews', 'WSU Pharmacy & Health Sciences', 'Black__Raven', 'Aliyu bn uthman', 'Manjinder Singh Sirsa', 'UKNewsRetweets', 'Science Magazine', 'Abhijeet Kumar', 'Santana-Enderson', 'Depressed Cavs Fan.', 'Isaac Bogoch', 'Dr. Theresa Tam', 'André  ...
# {'DeepFriedTurkey': 'Deep-Sea Civility Predator', 'Deep-Sea Civility Predator': 'Marcia Lusk', 'Marni Halasa': 'Preserve Our Brooklyn Neighborhoods', 'janlynn': 'Francesco M.', 'Sam': 'Eric Haywood', 'Mads C': 'Eric Haywood', 'Raffles': 'Martyn McLaughlin', 'Helen Miller': 'Martyn McLaughlin', 'kathycybele #MaskItOrCasket when you are not @home': 'Rep. Jared Huffman', 'Neil Born': 'Rep. Jared Huffman', 'Proud Conservative Scum': 'Rep. Jared Huffman', 'BettyJeanL': 'W. Tai', 'Juliethe RealJules': 'Rep. Jared Huffman', 'Jeff (((BLM))) Krasner': 'Rep. Jared Huffman', 'Freedom of the Truth🙏🇺🇸🇮🇱': 'software_autist 🇳🇱🇺🇸', 'Eileen': 'Ted Lieu', '★★ 𝕯𝖊𝖎𝖉𝖗𝖆 𝕶𝖆𝖙𝖍𝖑𝖊𝖊𝖓': 'Rep. Jared Huffman', 'brian': 'Rep. Jared Huffman', 'Greg': 'Stephanie Ruhle', 'Melissa Batchelor, PhD, RN, FNP, FAAN': 'GW School of Nursing', 'MDLIVE': 'GW School of Nursing', 'Fesmisol Yasmitacion': 'GW School of Nursing', 'Steven Cooke': 'Geoffrey Miller', 'Ayoku': 'Geoffrey Miller', 'Tsogbayar Tsednee': 'Geoffrey Miller', 'Charday': 'Geoffrey Miller', 'Chase Clark': 'ian haydon', 'Wild West': 'Brad Little', '📝 Nelly Luna Amancio': 'Gottfried Gillich', 'v.': 'Ami👩🏿\u200d\U0001f9b2🍑💙', 'alison': 'katie "downballot races" orenstein', 'Berenice': 'Negro Kekashi 🍃', 'HOLDEN REGNiER': 'Negro Kekashi 🍃', 'savannah': 'Negro Kekashi 🍃', 'SBJK': 'Negro Kekashi 🍃', 'Negro Kekashi 🍃': 'Marcia Lusk', 'Spencer Hardwick': 'Negro Kekashi 🍃', '🌿': 'Negro Kekashi 🍃', 'Setty': 'Negro Kekashi 🍃', 'Jessica Brown': 'Negro Kekashi 🍃', 'إبن الغُبيري': 'Iran Front Page', 'Kurekureto': 'LBC News', 'Mook Atman': 'Iran Front Page', 'taseenb': 'Revolution Now', 'Nihal Mirza': 'Wars on the Brink', 'Richard Taylor': 'Hananya Naftali', 'Joel Guy': 'Philippa Gray', 'Elly Nowell': 'Philippa Gray', 'Sue Freeman MacDonald': 'Navid Akhtar 🇵🇰', 'Navid Akhtar 🇵🇰': 'Marcia Lusk', 'DRA. KARLA CORDOVA': 'Navid Akhtar 🇵🇰', 'Marcela Mejía': 'Navid Akhtar 🇵🇰', 'lynnette rañada': 'Navid Akhtar 🇵🇰', 'piupiuu': 'Navid Akhtar 🇵🇰', 'Meyyrei⁷ 💜': 'Navid Akhtar 🇵🇰', 'Ulfat Bangash': 'Navid Akhtar 🇵🇰', 'Dr.rayyan alwazzan': 'Navid Akhtar 🇵🇰', 'andrew mukembo🇺🇬🇯🇲': 'Navid Akhtar 🇵🇰', 'Elena Boldeanu, M.D.': 'Navid Akhtar 🇵🇰', 'Jolo Garcia': 'Navid Akhtar 🇵🇰', 'Vishnu Reddy': 'Navid Akhtar 🇵🇰', 'Amanda 😷': 'Navid Akhtar 🇵🇰', 'MEHRAN NMZ ☆': 'Navid Akhtar 🇵🇰', 'Achieng Abondo 🇰🇪': 'Navid Akhtar 🇵🇰', 'CG_Zha Liyou查立友': 'Navid Akhtar 🇵🇰', 'sylvia': 'Navid Akhtar 🇵🇰', 'Ex Libris Research Solutions': 'interRel Consulting', 'Summer Watson': 'interRel Consulting', 'Carolarojas': 'interRel Consulting', 'Mantoria Inc': 'interRel Consulting', '👠Beyond Blonde 👠': 'W. Tai', 'Adhoc': 'W. Tai', 'Rattlecans': 'W. Tai', 'docleslie': 'W. Tai', 'Snuffy': 'W. Tai', 'W. Tai': 'Marcia Lusk', 'Glow Queen ✨': 'W. Tai', '💛The New Regine Normal🕊': 'W. Tai', 'Istoryk': 'W. Tai', 'Monica Zaldivar🎗': 'W. Tai', 'Paul Gerard': 'W. Tai', 'Zack 🏳️\u200d🌈🌹💛💚': 'W. Tai', 'Stephanie R Fredrickson': 'W. Tai', 'Follower of Idiots': 'W. Tai', 'Mrs Stephanie Amoako 🇬🇭🇯🇲🌎🥃': 'W. Tai', 'Content Writer': 'W. Tai', 'cool girl': 'W. Tai', 'Jeannie renton': 'W. Tai', 'Miss B': 'W. Tai', 'svtrash': 'ANCX', 'Drei💦': 'ANCX', 'ajunice': 'ANCX', 'Donna Desiderio': 'ANCX', 'Blue Wave Rider2020': 'Reuters', 'Diego Hernandez': 'Reuters', 'Duwli  Toe': 'Reuters', 'Aroguden': 'Reuters', 'Dan Jordan': 'Reuters', 'Kwame': 'Reuters', 'CJ Baxter': 'Reuters', 'Bohring': 'Reuters', '🔮TINA MARIE MONTGOMERY🔮': 'Danni_D', 'Retired Attorney': 'Reuters', 'Cupcake Twinkie': 'Reuters', 'Maranola': 'Reuters', 'Zoe Trndsttr': 'Reuters', 'Denison Denizen': 'Reuters', 'helme hanafi': 'Reuters', 'Evan A. Laksmana': 'Reuters', 'Faryad Azadi': 'Heshmat Alavi', '3g :)': 'Heshmat Alavi', 'Sharon Apple': 'Scott Stedman', 'marcus': 'Sam Hockley-Smith', 'Tatiana Rodríguez': 'Lauren', 'Christina the police are targeting journalists OC': 'Foxy Brown', 'Jody Goldenfield': 'Foxy Brown', 'kayla': 'Eric Haywood', 'Rachel A. Adler': 'Galavant', 'Andrew Chen': 'Galavant', 'Steve Duncan': 'Galavant', '(((ta ...
# Counter({'Marcia Lusk': 1727, 'Eric Haywood': 407, 'Dr. Dena Grayson': 186, 'Ted Lieu': 145, 'Ujjwal Poudel🌎🌳': 136, 'Navid Akhtar 🇵🇰': 135, 'Eunice Yoon': 128, 'Danni_D': 95, 'Negro Kekashi 🍃': 89, 'muhammad faiz': 86, 'katie "downballot races" orenstein': 85, 'Scott Semple': 84, 'Coronavirus Updates - Alexander Higgins': 81, 'Stephanie Ruhle': 76, 'BBC Reality Check': 68, 'Reuters': 64, 'भारतीय': 63, 'brandon 🏁': 62, 'kiuku': 59, 'Heshmat Alavi': 54, 'The New Indian Express': 44, 'SkyNews': 44, 'Sabine Slaughter': 43, 'Candace Owens': 42, 'Donald J. Trump': 41, 'Bloomberg QuickTake': 40, "Miriam O'Callaghan": 38, 'The Brown Institute': 36, 'W. Tai': 35, 'PRO Defence Tezpur (Assam/Arunachal Pradesh)': 35, 'Dr. Theresa Tam': 34, 'Anita M endeman (#PrismSofia RS3)': 34, 'Roel Raymond': 33, 'James Woods': 32, 'Savitri S': 32, 'MuslimMarine': 31, 'craig newmark': 30, 'NCDC': 30, 'Wars on the Brink': 29, 'Bloomberg': 29, 'Daedria✨': 29, 'Rea Prouska': 28, 'Rudaw English': 28, 'Flagrare 🔥': 27, 'Sarah Buduson': 27, 'The Connect 🔌.': 26, 'Meter Maid': 26, 'Last Surviving Braincell': 25, 'Paula Vernimmen': 25, 'Rep. Jared Huffman': 24, 'China Daily': 24, 'Marion  Danganan': 24, 'E Goodman': 24, 'Jennifer Cruz': 24, '(((Blue Dilly Gal)))': 24, 'Sukhmani Bal, MPH': 23, 'Antonio Ugarte': 22, 'Ridɑ': 22, 'Rick Evans 🖐️ #BlackLivesMatter ⌛️': 22, 'Rheumatoid Patient': 21, 'Isaac Bogoch': 20, 'Waimiri': 20, 'matt \U0001f99d': 20, 'Scott Shafer': 19, 'Wooggie': 19, 'MEAWW Entertainment': 19, 'Delighted Kougar': 19, 'Pepe13': 19, 'Jameson Lopp': 18, 'Katie Williams': 18, 'David Sinclair, PhD': 17, 'Holger Hank': 17, 'World Health Organization (WHO)': 17, 'André Picard': 17, 'Saad hussain': 17, 'The Real Oloo': 17, 'vidyut kaji': 17, 'momZsa': 17, 'Agent Broflake': 16, 'kewkies🔞': 16, 'I Just Want The Truth. Period!': 16, 'amadecasa 出かける前にも手を洗う': 16, 'Martyn McLaughlin': 15, 'Donna Young': 15, 'Dan Milano #BlackLivesMatter': 15, 'Chris Riedel': 15, 'Zoe Daniel': 15, '𝕋𝕠𝕞𝕞𝕪': 15, '재즈미나🖤\U0001f9a2': 15, 'Venture Capital': 14, 'Jan Smolaga': 14, 'CapricornFM News': 14, 'Tracy - We Must be better than this!': 14, 'Harry Pailas': 14, 'William Velazco': 14, 'Alecia Pratt': 14, 'sandrina carosso': 14, '#SHIFT': 14, '✝️Shirley✝️': 14, 'Stephen Elder': 14, 'Leah Millis': 14, 'Yeruvaka': 14, 'Carrie Gallagher': 14, 'Sam Hockley-Smith': 13, 'Flutura Kusari': 13, 'Neeld': 13, 'Kanchan Gupta': 13, 'Megaphone UK': 13, 'Sibesh Kar': 13, 'Cece - The Masks are the Medicine #MaskUp': 13, 'Queen B✨': 13, 'David L Hardy': 13, 'Rapscallion': 13, 'Valynn': 13, 'Senator Jordon Steele-John 🌏🔥': 13, 'Geoffrey Miller': 12, 'Molly Jong-Fast🏡': 12, 'Aliyu bn uthman': 12, 'SoCal MFG': 12, 'Michelle Wong': 12, 'Rox ✌🏻❤️ 🇺🇸': 12, 'Lisa Sharon Harper': 12, 'Valladolid_Exterior': 11, 'Sarah Abdallah': 11, 'T.PRAVEEN': 11, 'Andy Biotech': 11, 'Emmy van Deurzen☀️🌍 🌼🌹🌳🇪🇺🇫🇷🇳🇱🇬🇧🇺🇸⭐️': 11, 'Dr. Nahid Bhadelia "Masks,Tests,PPE & Leadership"': 11, '𝓚.🎪': 11, 'Touqir Abbas': 11, 'naniuddin': 11, '🍰Msbear🍰': 11, 'Danielle Smith': 11, 'Melissa Hudson': 11, '自由中國♥撐香港': 11, 'Erin Bedford': 11, '𝗪𝗶𝗻𝘀𝘁𝗼𝗻 𝗣𝗼𝗻': 11, '☻ SMILE ☻': 11, 'Gregory Bledsoe MD MPH': 11, 'CMHA National': 11, 'IndianPremierLeague': 11, 'Martin Williams': 11, 'UGA': 11, 'Miria  C.': 11, 'Revolution Now': 10, 'Stella Garber': 10, 'FluTrackers.com': 10, 'Briahna Joy Gray': 10, 'Benji Button': 10, 'Tina Morphis #KHive #Humanist #ForthePeople': 10, '11111111': 10, 'Corey Uhden': 10, 'Vishal': 10, 'Kelly 💕🇪🇺 Animal Activist 🇪🇺 EU Citizen': 10, 'Amanda🌍 #FreeNazanin #FreeNarges': 10, 'Jamie Dempsey': 10, 'Bryce Avary': 10, 'Qaziinc': 10, 'Sacred Heart Catholic Primary School and Nursery': 10, 'The Midnight-Blue Don': 9, 'Eric Feigl-Ding': 9, 'Willow Curry': 9, 'Rob Morris': 9, 'Kingshills Estate Agents': 9, 'AFP news agency': 9, 'UrbanLibrariansUnite': 9, 'Martina Navratilova': 9, 'Mohammad Omair': 9, 'Paul Kadak': 9, 'Deetz': 9, 'Emzy': 9, 'underdog777': 9, 'David Vance': 9, 'aTom': 9, 'Paul Peyton': 9, 'Gordon Brookes': 9, ...
# Marcia Lusk
# Eric Haywood
# Ted Lieu
# Stephanie Ruhle
# katie "downballot races" orenstein
# Negro Kekashi 🍃
# Navid Akhtar 🇵🇰
# Reuters
# Danni_D
# Heshmat Alavi
# Coronavirus Updates - Alexander Higgins
# भारतीय
# Eunice Yoon
# muhammad faiz
# BBC Reality Check
# Dr. Dena Grayson
# kiuku
# brandon 🏁
# Scott Semple
# Ujjwal Poudel🌎🌳
# 20
